# %%
import numpy as np
import plotly
import plotly.graph_objects
import plotly.express as px
import ipywidgets
import IPython.display


def parabola(x, y, slider_value=1.0):
    return slider_value*x*x+y*x


def square(x, y, slider_value=1.0):
    return slider_value*((x-y))**2


min_x = -5.0
max_x = 5.0
n_slices = 10
n_scales = 5

figure = plotly.graph_objects.FigureWidget(
    [plotly.graph_objects.Surface(), plotly.graph_objects.Surface(), plotly.graph_objects.Surface(), plotly.graph_objects.Surface(), plotly.graph_objects.Surface(), plotly.graph_objects.Scatter3d()] + [
        plotly.graph_objects.Scatter3d() for _ in range(2*n_slices)
    ] + [
        plotly.graph_objects.Surface() for _ in range(n_scales)
    ], plotly.graph_objects.Layout(scene={'xaxis_title': "X axis", 'yaxis_title': "Y axis", 'zaxis_title': "Z axis"}),
)
figure.update_layout(showlegend=False)


def update_surface(change):
    selected_value = change["new"]
    ox = np.linspace(min_x, max_x, 50)
    oy = np.linspace(min_x, max_x, 50)
    xy, yx = np.meshgrid(ox, oy)
    z_parabola = parabola(xy, yx)
    square_parabola = square(xy, yx)
    selected_id = np.searchsorted(oy, selected_value)
    max_z = z_parabola.max()
    with figure.batch_update():
        surface = figure.data[3]
        surface.colorscale = px.colors.sequential.Inferno
        surface.opacity = 0.7
        surface.x = xy
        surface.y = yx
        surface.z = z_parabola

        slider_parabola = square(xy, yx)
        selected_scatter = figure.data[4]
        selected_scatter.colorscale = px.colors.sequential.Viridis
        selected_scatter.opacity = 0.7
        selected_scatter.x = xy
        selected_scatter.y = yx
        selected_scatter.z = square_parabola

        XoY = figure.data[0]
        XoY.colorscale = px.colors.sequential.Inferno
        XoY.opacity = 0.2
        XoY.surfacecolor = xy + yx
        XoY.x = xy
        XoY.y = yx
        XoY.z = np.zeros_like(xy)

        min_z = min(z_parabola.min(), slider_parabola.min())
        max_z = max(z_parabola.max(), slider_parabola.max())
        oz = np.linspace(min_z, max_z, 2)
        plane_xz, plane_zx = np.meshgrid(ox, oz)
        XoZ = figure.data[1]
        XoZ.colorscale = px.colors.sequential.Viridis
        XoZ.opacity = 0.2
        XoZ.surfacecolor = plane_xz + plane_zx
        XoZ.x = plane_xz
        XoZ.y = np.zeros_like(plane_xz)
        XoZ.z = plane_zx

        YoZ = figure.data[2]
        YoZ.colorscale = px.colors.sequential.Cividis
        YoZ.opacity = 0.2
        YoZ.surfacecolor = plane_xz + plane_zx
        YoZ.x = np.zeros_like(plane_zx)
        YoZ.y = plane_xz
        YoZ.z = plane_zx

        scatter = figure.data[5]
        scatter.mode="lines"
        scatter.line=dict(color='red', width=4)
        argmin = slider_parabola[selected_id].argmin()
        scatter.x = np.full([2], ox[argmin])
        scatter.y=[selected_value, selected_value]
        scatter.z=[slider_parabola[selected_id, argmin], max_z]

        traces_iter = iter(figure.data)
        next(traces_iter)
        next(traces_iter)
        next(traces_iter)
        next(traces_iter)
        next(traces_iter)
        next(traces_iter)
        for y_coordinate in np.linspace(min_x, max_x, n_slices):
                expanded_y_temp = np.ones_like(xy) * y_coordinate
                z_2d_temp = parabola(xy, expanded_y_temp)
                scatter = next(traces_iter)
                scatter.x = xy.flatten().copy()
                scatter.y=expanded_y_temp.flatten().copy()
                scatter.z=z_2d_temp.flatten().copy()
                scatter.mode="lines"
                scatter.line=dict(color="black", width=1)
                scatter = next(traces_iter)
                argmin = z_2d_temp.argmin()
                scatter.x=[xy.flatten()[argmin], xy.flatten()[argmin]]
                scatter.y=[y_coordinate, y_coordinate]
                scatter.z=[z_2d_temp.flatten()[argmin], max_z]
                scatter.mode="lines"
                scatter.line=dict(color='black', width=1)
        surface_id = 0
        for surface in traces_iter:
            surface_color = plotly.colors.sample_colorscale(px.colors.sequential.Inferno, surface_id / (n_scales-1))[0]
            surface.colorscale = [(0.0, surface_color), (1.0, surface_color)]
            surface.opacity = 0.7
            surface.x = xy
            surface.y = yx
            surface.z = parabola(xy, yx, surface_id + 1)
            surface_id += 1
    with figure.batch_update():
        min_z = 9e9
        max_z = -9e9
        for surface in figure.data:
            if not isinstance(surface.z, tuple) and surface.z is not None:
                min_z = min(min_z, surface.z.min())
                max_z = max(max_z, surface.z.max())
        oz = np.linspace(min_z, max_z, 2)
        plane_xz, plane_zx = np.meshgrid(ox, oz)
        XoZ = figure.data[1]
        XoZ.colorscale = px.colors.sequential.Viridis
        XoZ.opacity = 0.2
        XoZ.surfacecolor = plane_xz + plane_zx
        XoZ.x = plane_xz
        XoZ.y = np.zeros_like(plane_xz)
        XoZ.z = plane_zx

        YoZ = figure.data[2]
        YoZ.colorscale = px.colors.sequential.Cividis
        YoZ.opacity = 0.2
        YoZ.surfacecolor = plane_xz + plane_zx
        YoZ.x = np.zeros_like(plane_zx)
        YoZ.y = plane_xz
        YoZ.z = plane_zx


update_surface({'new': 0.0})
slider = ipywidgets.FloatSlider(min=-10.0, max=10.0, step=1.0)
slider.observe(update_surface, names="value")
IPython.display.display(slider, figure)
# Out:
# FloatSlider(value=0.0, max=10.0, min=-10.0, step=1.0)
# FigureWidget({
#     'data': [{'colorscale': [[0.0, '#000004'], [0.1111111111111111, '#1b0c41'],
#                              [0.2222222222222222, '#4a0c6b'], [0.3333333333333333,
#                              '#781c6d'], [0.4444444444444444, '#a52c60'],
#                              [0.5555555555555556, '#cf4446'], [0.6666666666666666,
#                              '#ed6925'], [0.7777777777777778, '#fb9b06'],
#                              [0.8888888888888888, '#f7d13d'], [1.0, '#fcffa4']],
#               'opacity': 0.2,
#               'surfacecolor': {'bdata': ('AAAAAAAAJMDmFLycgpcjwMwpeDkFLy' ... 'g5BS8jQOYUvJyClyNAAAAAAAAAJEA='),
#                                'dtype': 'f8',
#                                'shape': '50, 50'},
#               'type': 'surface',
#               'uid': '4cbc1c6b-9315-4dd2-bbe0-6d395cd6d439',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'y': {'bdata': ('AAAAAAAAFMAAAAAAAAAUwAAAAAAAAB' ... 'AAAAAUQAAAAAAAABRAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'z': {'bdata': ('AAAAAAAAAAAAAAAAAAAAAAAAAAAAAA' ... 'AAAAAAAAAAAAAAAAAAAAAAAAAAAAA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'}},
#              {'colorscale': [[0.0, '#440154'], [0.1111111111111111, '#482878'],
#                              [0.2222222222222222, '#3e4989'], [0.3333333333333333,
#                              '#31688e'], [0.4444444444444444, '#26828e'],
#                              [0.5555555555555556, '#1f9e89'], [0.6666666666666666,
#                              '#35b779'], [0.7777777777777778, '#6ece58'],
#                              [0.8888888888888888, '#b5de2b'], [1.0, '#fde725']],
#               'opacity': 0.2,
#               'surfacecolor': {'bdata': ('0XUPz6p+JsC3istrLRYmwJ2fhwiwrS' ... 'dT8FJjQE7Byyl4WWNAAAAAAABgY0A='),
#                                'dtype': 'f8',
#                                'shape': '2, 50'},
#               'type': 'surface',
#               'uid': 'ce0bdf63-1ba9-4a92-bd6b-1a8b4d28ed1e',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '2, 50'},
#               'y': {'bdata': ('AAAAAAAAAAAAAAAAAAAAAAAAAAAAAA' ... 'AAAAAAAAAAAAAAAAAAAAAAAAAAAAA='),
#                     'dtype': 'f8',
#                     'shape': '2, 50'},
#               'z': {'bdata': ('ousenlX9GMCi6x6eVf0YwKLrHp5V/R' ... 'AAAMBiQAAAAAAAwGJAAAAAAADAYkA='),
#                     'dtype': 'f8',
#                     'shape': '2, 50'}},
#              {'colorscale': [[0.0, '#00224e'], [0.1111111111111111, '#123570'],
#                              [0.2222222222222222, '#3b496c'], [0.3333333333333333,
#                              '#575d6d'], [0.4444444444444444, '#707173'],
#                              [0.5555555555555556, '#8a8678'], [0.6666666666666666,
#                              '#a59c74'], [0.7777777777777778, '#c3b369'],
#                              [0.8888888888888888, '#e1cc55'], [1.0, '#fee838']],
#               'opacity': 0.2,
#               'surfacecolor': {'bdata': ('0XUPz6p+JsC3istrLRYmwJ2fhwiwrS' ... 'dT8FJjQE7Byyl4WWNAAAAAAABgY0A='),
#                                'dtype': 'f8',
#                                'shape': '2, 50'},
#               'type': 'surface',
#               'uid': '428d7506-e469-4fe2-bef3-f712b3715a75',
#               'x': {'bdata': ('AAAAAAAAAAAAAAAAAAAAAAAAAAAAAA' ... 'AAAAAAAAAAAAAAAAAAAAAAAAAAAAA='),
#                     'dtype': 'f8',
#                     'shape': '2, 50'},
#               'y': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '2, 50'},
#               'z': {'bdata': ('ousenlX9GMCi6x6eVf0YwKLrHp5V/R' ... 'AAAMBiQAAAAAAAwGJAAAAAAADAYkA='),
#                     'dtype': 'f8',
#                     'shape': '2, 50'}},
#              {'colorscale': [[0.0, '#000004'], [0.1111111111111111, '#1b0c41'],
#                              [0.2222222222222222, '#4a0c6b'], [0.3333333333333333,
#                              '#781c6d'], [0.4444444444444444, '#a52c60'],
#                              [0.5555555555555556, '#cf4446'], [0.6666666666666666,
#                              '#ed6925'], [0.7777777777777778, '#fb9b06'],
#                              [0.8888888888888888, '#f7d13d'], [1.0, '#fcffa4']],
#               'opacity': 0.7,
#               'type': 'surface',
#               'uid': 'cbbd7242-89b8-4037-92a6-9e3a13bc3177',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'y': {'bdata': ('AAAAAAAAFMAAAAAAAAAUwAAAAAAAAB' ... 'AAAAAUQAAAAAAAABRAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'z': {'bdata': ('AAAAAAAASUAad4OPfn1HQKg/i6amBU' ... 'umpgVGQBp3g49+fUdAAAAAAAAASUA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'}},
#              {'colorscale': [[0.0, '#440154'], [0.1111111111111111, '#482878'],
#                              [0.2222222222222222, '#3e4989'], [0.3333333333333333,
#                              '#31688e'], [0.4444444444444444, '#26828e'],
#                              [0.5555555555555556, '#1f9e89'], [0.6666666666666666,
#                              '#35b779'], [0.7777777777777778, '#6ece58'],
#                              [0.8888888888888888, '#b5de2b'], [1.0, '#fde725']],
#               'opacity': 0.7,
#               'type': 'surface',
#               'uid': 'a4d4d1a0-9fb1-44ec-904c-302e94d4403f',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'y': {'bdata': ('AAAAAAAAFMAAAAAAAAAUwAAAAAAAAB' ... 'AAAAAUQAAAAAAAABRAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'z': {'bdata': ('AAAAAAAAAAAp66IID1OlPynroggPU8' ... 'IID1PFPynroggPU6U/AAAAAAAAAAA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'}},
#              {'line': {'color': 'red', 'width': 4},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '1890024d-5d30-4fe4-8e44-c11a71e2a730',
#               'x': {'bdata': 'gMb60Fgfuj+AxvrQWB+6Pw==', 'dtype': 'f8'},
#               'y': [0.0, 0.0],
#               'z': [0.0, 100.0]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '215f3f69-2309-4d3a-acad-f2f025c2d06d',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAAAAAFMAAAAAAAAAUwAAAAAAAAB' ... 'AAAAAUwAAAAAAAABTAAAAAAAAAFMA='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('AAAAAAAASUAad4OPfn1HQKg/i6amBU' ... 'Ukzfz9v2BJrxT+Ue+/AAAAAAAAAAA='),
#                     'dtype': 'f8'}},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': 'decb9c47-f884-4d9e-b19d-d8ecd64b7e75',
#               'x': [2.5510204081632653, 2.5510204081632653],
#               'y': [-5.0, -5.0],
#               'z': [-6.247396917950853, 100.0]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': 'b1eb5594-26dc-465c-bef5-4ac7c6e9ab55',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('x3Ecx3EcD8DHcRzHcRwPwMdxHMdxHA' ... 'zHcRwPwMdxHMdxHA/Ax3Ecx3EcD8A='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('juM4juM4RkAvqmuAaNNEQETCIvqWeE' ... 'U0lNIJQCh+KLZwZhFAkOM4juM4FkA='),
#                     'dtype': 'f8'}},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '6be654f6-0ced-43a1-a4cb-b7707ea1b00e',
#               'x': [1.9387755102040813, 1.9387755102040813],
#               'y': [-3.888888888888889, -3.888888888888889],
#               'z': [-3.7808320607154426, 100.0]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': 'c2eddd88-b9b0-46ce-b1a6-aa89b71122ed',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('juM4juM4BsCO4ziO4zgGwI7jOI7jOA' ... 'iO4zgGwI7jOI7jOAbAjuM4juM4BsA='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('HMdxHMdxQ0BE3VNxUilCQOFEuk2H60' ... '++46ggQL9yc5eQWyNAjuM4juM4JkA='),
#                     'dtype': 'f8'}},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': 'ccbb31f3-07e0-4c77-be0d-5f543d8450eb',
#               'x': [1.3265306122448983, 1.3265306122448983],
#               'y': [-2.7777777777777777, -2.7777777777777777],
#               'z': [-1.925123791013004, 100.0]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '6076a788-ce28-4b0f-9409-9bc48873fef9',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('qqqqqqqq+r+qqqqqqqr6v6qqqqqqqv' ... 'qqqqr6v6qqqqqqqvq/qqqqqqqq+r8='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('qqqqqqqqQEC0IHjEeP4+QPyOo0LvvD' ... 'FwIt0qQGmm0tPoAy5Aq6qqqqqqMEA='),
#                     'dtype': 'f8'}},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': 'e0572b52-bde5-4ec7-9017-833d3bd1e11d',
#               'x': [0.9183673469387754, 0.9183673469387754],
#               'y': [-1.6666666666666665, -1.6666666666666665],
#               'z': [-0.6872136609745938, 100.0]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '9121623c-fa8d-48c9-8a04-d9607732017e',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('cBzHcRzH4b9wHMdxHMfhv3Acx3Ecx+' ... 'dxHMfhv3Acx3Ecx+G/cBzHcRzH4b8='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('chzHcRzHO0DehkimTKo5QDWU0unPoj' ... 'GRsIgyQArtGIggVjRAjuM4juM4NkA='),
#                     'dtype': 'f8'}},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '5636399b-71ed-441b-bd80-a1535e1a79e4',
#               'x': [0.3061224489795915, 0.3061224489795915],
#               'y': [-0.5555555555555554, -0.5555555555555554],
#               'z': [-0.07635707344162149, 100.0]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '3f3f6c43-43b0-41fc-8926-7f9eacf8f64e',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('cBzHcRzH4T9wHMdxHMfhP3Acx3Ecx+' ... 'dxHMfhP3Acx3Ecx+E/cBzHcRzH4T8='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('juM4juM4NkAK7RiIIFY0QG+ZAZGwiD' ... 'Lpz6I3QN6GSKZMqjlAchzHcRzHO0A='),
#                     'dtype': 'f8'}},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': 'bc45f42a-d87d-4e5a-931d-6fe8c0a124f0',
#               'x': [-0.3061224489795915, -0.3061224489795915],
#               'y': [0.5555555555555554, 0.5555555555555554],
#               'z': [-0.07635707344162149, 100.0]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': 'f9f4f6f7-481c-4704-9850-1b8d5717d5bd',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('rKqqqqqq+j+sqqqqqqr6P6yqqqqqqv' ... 'qqqqr6P6yqqqqqqvo/rKqqqqqq+j8='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('qqqqqqqqMEBoptLT6AMuQE89YXAi3S' ... 'NC77w8QLQgeMR4/j5Aq6qqqqqqQEA='),
#                     'dtype': 'f8'}},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '8243c9b4-18f4-4bd5-a783-c602153a060a',
#               'x': [-0.9183673469387754, -0.9183673469387754],
#               'y': [1.666666666666667, 1.666666666666667],
#               'z': [-0.6872136609745942, 100.0]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '82172d95-d937-4bdd-adbd-1f794d2dfa14',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('kOM4juM4BkCQ4ziO4zgGQJDjOI7jOA' ... 'iO4zgGQJDjOI7jOAZAkOM4juM4BkA='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('jOM4juM4JkC8cnOXkFsjQMFHv77jqC' ... 'pNh+tAQEXdU3FSKUJAHcdxHMdxQ0A='),
#                     'dtype': 'f8'}},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '6cc246c8-ca4c-443c-aab3-70f945c48c89',
#               'x': [-1.3265306122448979, -1.3265306122448979],
#               'y': [2.7777777777777786, 2.7777777777777786],
#               'z': [-1.9251237910130046, 100.0]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '460c6089-d39b-4445-927b-94c0999c9546',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('yHEcx3EcD0DIcRzHcRwPQMhxHMdxHA' ... 'zHcRwPQMhxHMdxHA9AyHEcx3EcD0A='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('jOM4juM4FkAofii2cGYRQNBIdTSU0g' ... 'L6lnhDQC+qa4Bo00RAjuM4juM4RkA='),
#                     'dtype': 'f8'}},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '01492073-d7b7-4234-bd25-c3968b2d0532',
#               'x': [-1.9387755102040813, -1.9387755102040813],
#               'y': [3.8888888888888893, 3.8888888888888893],
#               'z': [-3.7808320607154435, 100.0]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '074be1aa-c70a-4f44-832b-4d8a055c6240',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAAAAAFEAAAAAAAAAUQAAAAAAAAB' ... 'AAAAAUQAAAAAAAABRAAAAAAAAAFEA='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('AAAAAAAAAABgSa8U/lHvv8AaJSTN/P' ... 'umpgVGQBp3g49+fUdAAAAAAAAASUA='),
#                     'dtype': 'f8'}},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '6dbb57a1-50c3-40ee-a281-16085f352f5a',
#               'x': [-2.5510204081632653, -2.5510204081632653],
#               'y': [5.0, 5.0],
#               'z': [-6.247396917950853, 100.0]},
#              {'colorscale': [[0.0, 'rgb(0, 0, 4)'], [1.0, 'rgb(0, 0, 4)']],
#               'opacity': 0.7,
#               'type': 'surface',
#               'uid': '2ae21a02-0aed-4a6f-916f-445d19fd8ef3',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'y': {'bdata': ('AAAAAAAAFMAAAAAAAAAUwAAAAAAAAB' ... 'AAAAAUQAAAAAAAABRAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'z': {'bdata': ('AAAAAAAASUAad4OPfn1HQKg/i6amBU' ... 'umpgVGQBp3g49+fUdAAAAAAAAASUA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'}},
#              {'colorscale': [[0.0, 'rgb(86, 16, 108)'], [1.0, 'rgb(86, 16, 108)']],
#               'opacity': 0.7,
#               'type': 'surface',
#               'uid': 'c7dd44a6-737a-4974-9b3d-4d976f3db2db',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'y': {'bdata': ('AAAAAAAAFMAAAAAAAAAUwAAAAAAAAB' ... 'AAAAAUQAAAAAAAABRAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'z': {'bdata': ('AAAAAADAUkAK6o3tzH5RQIgloGJDSF' ... 'BiQ0hQQArqje3MflFAAAAAAADAUkA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'}},
#              {'colorscale': [[0.0, 'rgb(186, 56, 83)'], [1.0, 'rgb(186, 56, 83)']],
#               'opacity': 0.7,
#               'type': 'surface',
#               'uid': 'f3912018-bd3a-4bc9-bb46-42e9f01a507f',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'y': {'bdata': ('AAAAAAAAFMAAAAAAAAAUwAAAAAAAAB' ... 'AAAAAUQAAAAAAAABRAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'z': {'bdata': ('AAAAAAAAWUCHGFqT2j5XQD2r+nGzjV' ... 'pxs41VQIcYWpPaPldAAAAAAAAAWUA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'}},
#              {'colorscale': [[0.0, 'rgb(248, 143, 14)'], [1.0, 'rgb(248, 143,
#                              14)']],
#               'opacity': 0.7,
#               'type': 'surface',
#               'uid': 'a22a2153-6d75-452e-b18b-093add34ee3b',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'y': {'bdata': ('AAAAAAAAFMAAAAAAAAAUwAAAAAAAAB' ... 'AAAAAUQAAAAAAAABRAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'z': {'bdata': ('AAAAAABAX0AERyY56P5cQPIwVYEj01' ... 'WBI9NaQARHJjno/lxAAAAAAABAX0A='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'}},
#              {'colorscale': [[0.0, 'rgb(252, 255, 164)'], [1.0, 'rgb(252, 255,
#                              164)']],
#               'opacity': 0.7,
#               'type': 'surface',
#               'uid': 'f75b929c-a3de-411d-adb1-425916c8b03d',
#               'x': {'bdata': ('AAAAAAAAFMDMKXg5BS8TwJhT8HIKXh' ... 'ByCl4SQMwpeDkFLxNAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'y': {'bdata': ('AAAAAAAAFMAAAAAAAAAUwAAAAAAAAB' ... 'AAAAAUQAAAAAAAABRAAAAAAAAAFEA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'},
#               'z': {'bdata': ('AAAAAADAYkDAOnnvel9hQFPbV8hJDG' ... 'fISQxgQMA6ee96X2FAAAAAAADAYkA='),
#                     'dtype': 'f8',
#                     'shape': '50, 50'}}],
#     'layout': {'scene': {'xaxis': {'title': {'text': 'X axis'}},
#                          'yaxis': {'title': {'text': 'Y axis'}},
#                          'zaxis': {'title': {'text': 'Z axis'}}},
#                'showlegend': False,
#                'template': '...'}
# })

# %% [markdown]
# TODO: y=x*x for complex numbers with 4D rotation: https://youtu.be/ZmRK9J3GkhM?si=1A2ZH1RjkwmdN6z
